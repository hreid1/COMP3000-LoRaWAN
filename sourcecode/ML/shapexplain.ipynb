# %%
from utils import DataLoader
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score
import shap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils import DataLoader
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 from sklearn.metrics import f1_score, accuracy_score
#
# ImportError: cannot import name 'DataLoader' from 'utils' (/Users/henry/.virtualenvs/djangodev/lib/python3.13/site-packages/utils/__init__.py)
